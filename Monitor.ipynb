# %%
data = [
    (1,"Laptop",2,50000),
    (2,"Mobile",3,20000),
    (3,"Watch",2,10000),
    (4,"Tablet",1,20000),
    (5,"Laptop",2,50000)
]
schema = ["id","product","quantity","price"]
df_b = spark.createDataFrame(data,schema)
record_count = df_b.count()
print(f"records Processed {record_count}")
if record_count == 0:
    raise Exception("No records found")
df_b.display()
