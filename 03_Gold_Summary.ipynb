# %%
df_g = spark.table("silver_sales")
from pyspark.sql.functions import *
gold_df = (df_g.groupBy("product")
           .agg(sum("Revenue")
            .alias("Total Revenue"))
           )
display(gold_df)
